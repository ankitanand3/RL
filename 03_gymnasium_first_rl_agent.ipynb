# %%
# 🔧 Setup: Run this cell first!
# Check GPU availability and install dependencies

import torch
import sys

# Check GPU
if torch.cuda.is_available():
    device = torch.device('cuda')
    print(f"✅ GPU available: {torch.cuda.get_device_name(0)}")
    print(f"   Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")
else:
    device = torch.device('cpu')
    print("⚠️ No GPU detected. Some cells may run slowly.")
    print("   Go to Runtime → Change runtime type → GPU")

print(f"\n📦 Python {sys.version.split()[0]}")
print(f"🔥 PyTorch {torch.__version__}")

# Set random seeds for reproducibility
import random
import numpy as np

SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

print(f"🎲 Random seed set to {SEED}")

# %matplotlib inline
# Out:
# ✅ GPU available: NVIDIA GB10
#    Memory: 130.7 GB
#
# 📦 Python 3.11.15
# 🔥 PyTorch 2.13.0+cu130
# 🎲 Random seed set to 42

# %%
# Install Gymnasium (run this once)
import subprocess
import sys

import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict

print("Gymnasium installed and imported.")
print(f"Gymnasium version: {gym.__version__}")
# Out:
# Gymnasium installed and imported.
# Gymnasium version: 1.2.2

# %%
# Let us explore what Gymnasium offers
# List some available environments

# Classic Controls are for physical world control problems
# Toy text is for decision making problems

env_categories = {
    'Classic Control': ['CartPole-v1', 'MountainCar-v0', 'Acrobot-v1', 'Pendulum-v1'],
    'Toy Text': ['FrozenLake-v1', 'Taxi-v3', 'CliffWalking-v1'],
}

print("Sample Gymnasium Environments:")
print("=" * 50)
for category, envs in env_categories.items():
    print(f"\n{category}:")
    for env_name in envs:
        try:
            env = gym.make(env_name)
            print(f"  {env_name}")
            print(f"    Action space:      {env.action_space}")
            print(f"    Observation space: {env.observation_space}")
            env.close()
        except Exception as e:
            print(f"  {env_name}: (not available: {e})")
# Out:
# Sample Gymnasium Environments:
# ==================================================
#
# Classic Control:
#   CartPole-v1
#     Action space:      Discrete(2)
#     Observation space: Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)
#   MountainCar-v0
#     Action space:      Discrete(3)
#     Observation space: Box([-1.2  -0.07], [0.6  0.07], (2,), float32)
#   Acrobot-v1
#     Action space:      Discrete(3)
#     Observation space: Box([ -1.        -1.        -1.        -1.       -12.566371 -28.274334], [ 1.        1.        1.        1.       12.566371 28.274334], (6,), float32)
#   Pendulum-v1
#     Action space:      Box(-2.0, 2.0, (1,), float32)
#     Observation space: Box([-1. -1. -8.], [1. 1. 8.], (3,), float32)
#
# Toy Text:
#   FrozenLake-v1
#     Action space:      Discrete(4)
#     Observation space: Discrete(16)
#   Taxi-v3
#     Action space:      Discrete(6)
#     Observation space: Discrete(500)
#   CliffWalking-v1
#     Action space:      Discrete(4)
#     Observation space: Discrete(48)

# %%
# Let us examine CartPole in detail
env = gym.make('CartPole-v1')

print("CartPole-v1 Environment Details")
print("=" * 50)
print(f"Action space: {env.action_space}")
print(f"  - 0: Push cart LEFT")
print(f"  - 1: Push cart RIGHT")
print()
print(f"Observation space: {env.observation_space}")
print(f"  - obs[0]: Cart position     (range: {env.observation_space.low[0]:.1f} to {env.observation_space.high[0]:.1f})")
print(f"  - obs[1]: Cart velocity     (range: {env.observation_space.low[1]:.1f} to {env.observation_space.high[1]:.1f})")
print(f"  - obs[2]: Pole angle (rad)  (range: {env.observation_space.low[2]:.4f} to {env.observation_space.high[2]:.4f})")
print(f"  - obs[3]: Pole angular vel  (range: {env.observation_space.low[3]:.1f} to {env.observation_space.high[3]:.1f})")
print()
print("Reward: +1 for every step the pole stays upright")
print("Episode ends when: pole angle > 12 deg, cart off screen, or 500 steps")
print(f"Max possible return: 500")

env.close()
# Out:
# CartPole-v1 Environment Details
# ==================================================
# Action space: Discrete(2)
#   - 0: Push cart LEFT
#   - 1: Push cart RIGHT
#
# Observation space: Box([-4.8               -inf -0.41887903        -inf], [4.8               inf 0.41887903        inf], (4,), float32)
#   - obs[0]: Cart position     (range: -4.8 to 4.8)
#   - obs[1]: Cart velocity     (range: -inf to inf)
#   - obs[2]: Pole angle (rad)  (range: -0.4189 to 0.4189)
#   - obs[3]: Pole angular vel  (range: -inf to inf)
#
# Reward: +1 for every step the pole stays upright
# Episode ends when: pole angle > 12 deg, cart off screen, or 500 steps
# Max possible return: 500

# %%
def run_random_agent(env_name, n_episodes=20, max_steps=500):
    """Run a random agent and record rewards."""
    env = gym.make(env_name)
    episode_rewards = []

    for ep in range(n_episodes):
        obs, info = env.reset(seed=ep)
        total_reward = 0

        for step in range(max_steps):
            action = env.action_space.sample()  # random action
            obs, reward, terminated, truncated, info = env.step(action)
            total_reward += reward

            if terminated or truncated:
                break

        episode_rewards.append(total_reward)
    env.close()
    return episode_rewards


# Test random agent on CartPole
random_rewards_cartpole = run_random_agent('CartPole-v1', n_episodes=100)

print("Random Agent on CartPole-v1:")
print(f"  Mean reward:   {np.mean(random_rewards_cartpole):.1f}")
print(f"  Std reward:    {np.std(random_rewards_cartpole):.1f}")
print(f"  Max reward:    {np.max(random_rewards_cartpole):.1f}")
print(f"  Min reward:    {np.min(random_rewards_cartpole):.1f}")
print(f"  Max possible:  500")
print()
print("The random agent averages about 20 steps -- terrible!")
print("The pole falls almost immediately with no intelligent control.")
# Out:
# Random Agent on CartPole-v1:
#   Mean reward:   21.8
#   Std reward:    11.8
#   Max reward:    81.0
#   Min reward:    9.0
#   Max possible:  500
#
# The random agent averages about 20 steps -- terrible!
# The pole falls almost immediately with no intelligent control.

# %%
def heuristic_cartpole(obs):
    """
    Simple heuristic for CartPole:
    If the pole is tilting right (positive angle), push right.
    If the pole is tilting left (negative angle), push left.
    """
    cart_pos, cart_vel, pole_angle, pole_angular_vel = obs

    # Push in the direction the pole is tilting
    if pole_angle + 0.1 * pole_angular_vel > 0:
        return 1  # push right
    else:
        return 0  # push left

def run_heuristic_agent(env_name, heuristic_fn, n_episodes=20, max_steps=500):
    """Run a heuristic agent and record rewards."""
    env = gym.make(env_name)
    episode_rewards = []

    for ep in range(n_episodes):
        obs, info = env.reset(seed=ep)
        total_reward = 0

        for step in range(max_steps):
            action = heuristic_fn(obs)
            obs, reward, terminated, truncated, info = env.step(action)
            total_reward += reward

            if terminated or truncated:
                break

        episode_rewards.append(total_reward)

    env.close()
    return episode_rewards

heuristic_rewards = run_heuristic_agent('CartPole-v1', heuristic_cartpole, n_episodes=100)

print("Heuristic Agent on CartPole-v1:")
print(f"  Mean reward:   {np.mean(heuristic_rewards):.1f}")
print(f"  Std reward:    {np.std(heuristic_rewards):.1f}")
print(f"  Max reward:    {np.max(heuristic_rewards):.1f}")
print(f"  Min reward:    {np.min(heuristic_rewards):.1f}")
print()
print("Much better! But the heuristic was hand-designed.")
print("Can an agent LEARN this behavior on its own?")
# Out:
# Heuristic Agent on CartPole-v1:
#   Mean reward:   500.0
#   Std reward:    0.0
#   Max reward:    500.0
#   Min reward:    500.0
#
# Much better! But the heuristic was hand-designed.
# Can an agent LEARN this behavior on its own?

# %%
# Compare random vs heuristic
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Histogram of episode lengths
axes[0].hist(random_rewards_cartpole, bins=20, alpha=0.7, label='Random', color='red')
axes[0].hist(heuristic_rewards, bins=20, alpha=0.7, label='Heuristic', color='green')
axes[0].set_xlabel('Episode Reward (steps survived)', fontsize=12)
axes[0].set_ylabel('Count', fontsize=12)
axes[0].set_title('Distribution of Episode Rewards', fontsize=14, fontweight='bold')
axes[0].legend(fontsize=11)
axes[0].axvline(x=500, color='gold', linestyle='--', label='Max possible', linewidth=2)
axes[0].legend(fontsize=11)

# Bar chart of means
means = [np.mean(random_rewards_cartpole), np.mean(heuristic_rewards)]
stds = [np.std(random_rewards_cartpole), np.std(heuristic_rewards)]
bars = axes[1].bar(['Random Agent', 'Heuristic Agent'], means, yerr=stds, capsize=5,
                    color=['red', 'green'], alpha=0.7)
axes[1].set_ylabel('Mean Episode Reward', fontsize=12)
axes[1].set_title('Random vs Heuristic Agent', fontsize=14, fontweight='bold')
axes[1].axhline(y=500, color='gold', linestyle='--', label='Max possible')
axes[1].legend(fontsize=11)

# Add value labels
for bar, mean in zip(bars, means):
    axes[1].text(bar.get_x() + bar.get_width()/2, bar.get_height() + 5,
                 f'{mean:.0f}', ha='center', fontsize=12, fontweight='bold')

plt.tight_layout()
plt.show()

print("The heuristic agent is dramatically better, but it required human insight.")
print("Next: let us build an agent that LEARNS the optimal behavior from scratch.")
# Out:
# The heuristic agent is dramatically better, but it required human insight.
# Next: let us build an agent that LEARNS the optimal behavior from scratch.

# %% [markdown]
# ### Explore the Environment

# %%
# TODO: Run a single episode of CartPole and print each step

env = gym.make('CartPole-v1')
obs, info = env.reset(seed=42)

print("Step-by-step CartPole episode:")
print(f"{'Step':>4} | {'Cart Pos':>9} | {'Cart Vel':>9} | {'Pole Angle':>11} | {'Angular Vel':>11} | {'Action':>6} | {'Reward':>6}")
print("-" * 80)


for step in range(20):
    cart_pos, cart_vel, pole_angle, pole_angular_vel = obs
    # TODO: Choose an action (try different strategies)
    # Option A: random
    # Option B: always push right (action=1)
    # Option C: push opposite to pole tilt

    # action = env.action_space.sample()  # This is Option A random
    # action = 1 # This is Option B always right

    # Option C:
    if pole_angle + 0.1 * pole_angular_vel > 0:
        action = 0  # push left
    else:
        action = 1  # push right

    next_obs, reward, terminated, truncated, info = env.step(action)

    action_name = 'LEFT' if action == 0 else 'RIGHT'
    print(f"{step:>4} | {obs[0]:>9.4f} | {obs[1]:>9.4f} | {obs[2]:>11.6f} | {obs[3]:>11.6f} | {action_name:>6} | {reward:>6.1f}")

    obs = next_obs
    if terminated or truncated:
        print(f"\nEpisode ended at step {step+1}")
        break
# Out:
# Step-by-step CartPole episode:
# Step |  Cart Pos |  Cart Vel |  Pole Angle | Angular Vel | Action | Reward
# --------------------------------------------------------------------------------
#    0 |    0.0274 |   -0.0061 |    0.035860 |    0.019737 |   LEFT |    1.0
#    1 |    0.0273 |   -0.2017 |    0.036255 |    0.323515 |   LEFT |    1.0
#    2 |    0.0232 |   -0.3973 |    0.042725 |    0.627407 |   LEFT |    1.0
#    3 |    0.0153 |   -0.5930 |    0.055273 |    0.933233 |   LEFT |    1.0
#    4 |    0.0034 |   -0.7889 |    0.073938 |    1.242760 |   LEFT |    1.0
#    5 |   -0.0123 |   -0.9849 |    0.098793 |    1.557658 |   LEFT |    1.0
#    6 |   -0.0320 |   -1.1810 |    0.129946 |    1.879456 |   LEFT |    1.0
#    7 |   -0.0557 |   -1.3773 |    0.167535 |    2.209486 |   LEFT |    1.0
#
# Episode ended at step 8

# %%
def improved_heuristic(obs):
    cart_pos, cart_vel, pole_angle, pole_angular_vel = obs

    position_threshold = 0.5

    if cart_pos > position_threshold:
        action = 0  # cart too far right → push left

    elif cart_pos < -position_threshold:
        action = 1  # cart too far left → push right

    else:
        predicted_pole_angle = pole_angle + 0.1 * pole_angular_vel

        if predicted_pole_angle > 0:
            action = 1  # pole moving right → push right
        else:
            action = 0  # pole moving left → push left

    return action
improved_rewards = run_heuristic_agent('CartPole-v1', improved_heuristic, n_episodes=100)

# %%
print(f"Improved Heuristic: mean={np.mean(improved_rewards):.1f}, max={np.max(improved_rewards):.1f}")
print(f"Original Heuristic: mean={np.mean(heuristic_rewards):.1f}, max={np.max(heuristic_rewards):.1f}")
# Out:
# Improved Heuristic: mean=493.2, max=500.0
# Original Heuristic: mean=500.0, max=500.0

# %%
class QLearningAgent:
    """
    Q-Learning agent for discrete state spaces.

    Q-learning update rule:
    Q(s, a) <- Q(s, a) + alpha * [r + gamma * max_a' Q(s', a') - Q(s, a)]

    We discretize the continuous CartPole observations into bins
    so we can use a simple table-based approach.
    """
    def __init__(self, n_actions, n_bins=10, alpha=0.1, gamma=0.99, epsilon=1.0, epsilon_decay=0.995, epsilon_min=0.01):
        self.n_actions = n_actions #Number of possible actions
        self.n_bins = n_bins # Discretization resolution
        self.alpha = alpha # Learning rate
        self.gamma = gamma # Discount factor
        self.epsilon = epsilon # Initial exploration probability
        self.epsilon_decay = epsilon_decay # Exploration multiplier
        self.epsilon_min = epsilon_min # Minimum exploration probability

        # Q-table: maps discretized state -> action values
        self.q_table = defaultdict(lambda: np.zeros(n_actions))

        # Bin edges for discretizing observations
        # CartPole: [cart_pos, cart_vel, pole_angle, pole_angular_vel]
        self.bins = [
            np.linspace(-2.4, 2.4, n_bins),      # cart position
            np.linspace(-3.0, 3.0, n_bins),       # cart velocity
            np.linspace(-0.21, 0.21, n_bins),     # pole angle
            np.linspace(-3.0, 3.0, n_bins),       # angular velocity
        ]

    def discretize(self, obs):
        """Convert continuous observation to discrete state."""
        state = []
        for i, val in enumerate(obs):
            idx = np.digitize(val, self.bins[i])
            state.append(idx)
        return tuple(state)

    def choose_action(self, state):
        """Epsilon-greedy action selection."""
        if np.random.random() < self.epsilon:
            return np.random.randint(self.n_actions)
        else:
            return np.argmax(self.q_table[state])

    def update(self, state, action, reward, next_state, done):
        """Q-learning update."""
        if done:
            target = reward
        else:
            target = reward + self.gamma * np.max(self.q_table[next_state])

        self.q_table[state][action] += self.alpha * (target - self.q_table[state][action])

    def decay_epsilon(self):
        """Reduce exploration rate over time."""
        self.epsilon = max(self.epsilon_min, self.epsilon * self.epsilon_decay)

print("Q-Learning Agent defined.")
print()
print("Key formula:")
print("  Q(s,a) <- Q(s,a) + alpha * [r + gamma * max Q(s',a') - Q(s,a)]")
print()
print("This is the fundamental update rule of Q-learning.")
print("The agent learns the value of each (state, action) pair from experience.")
# Out:
# Q-Learning Agent defined.
#
# Key formula:
#   Q(s,a) <- Q(s,a) + alpha * [r + gamma * max Q(s',a') - Q(s,a)]
#
# This is the fundamental update rule of Q-learning.
# The agent learns the value of each (state, action) pair from experience.

# %%
def train_q_agent(n_episodes=100000):
    """Train Q-learning agent on CartPole."""
    env = gym.make('CartPole-v1')
    agent = QLearningAgent(
        n_actions=env.action_space.n,
        n_bins=12,
        alpha=0.1,
        gamma=0.99,
        epsilon=1.0,
        epsilon_decay=0.998,
        epsilon_min=0.01,
    )

    episode_rewards = []
    best_reward = 0

    for ep in range(n_episodes):
        obs, info = env.reset(seed=ep % 100)
        state = agent.discretize(obs)
        total_reward = 0

        for step in range(500):
            action = agent.choose_action(state)
            next_obs, reward, terminated, truncated, info = env.step(action)
            next_state = agent.discretize(next_obs)
            done = terminated or truncated

            # Penalize falling
            if terminated and step < 499:
                reward = -10

            agent.update(state, action, reward, next_state, done)
            state = next_state
            total_reward += 1  # count steps survived

            if done:
                break

        episode_rewards.append(total_reward)
        agent.decay_epsilon()

        if total_reward > best_reward:
            best_reward = total_reward

        # Progress report
        if (ep + 1) % 500 == 0:
            recent = np.mean(episode_rewards[-100:])
            print(f"  Episode {ep+1:>5} | Recent avg: {recent:>6.1f} | Epsilon: {agent.epsilon:.3f} | Best: {best_reward}")

    env.close()
    return agent, episode_rewards

print("Training Q-learning agent on CartPole-v1...")
print("This learns from scratch -- no human knowledge built in.\n")
q_agent, q_rewards = train_q_agent(100000)
# Out:
# Training Q-learning agent on CartPole-v1...
# This learns from scratch -- no human knowledge built in.
#
#   Episode   500 | Recent avg:   47.1 | Epsilon: 0.368 | Best: 165
#   Episode  1000 | Recent avg:   93.0 | Epsilon: 0.135 | Best: 165
#   Episode  1500 | Recent avg:  106.5 | Epsilon: 0.050 | Best: 165
#   Episode  2000 | Recent avg:  115.3 | Epsilon: 0.018 | Best: 168
#   Episode  2500 | Recent avg:  120.2 | Epsilon: 0.010 | Best: 183
#   Episode  3000 | Recent avg:  121.4 | Epsilon: 0.010 | Best: 199
#   Episode  3500 | Recent avg:  127.7 | Epsilon: 0.010 | Best: 199
#   Episode  4000 | Recent avg:  126.9 | Epsilon: 0.010 | Best: 199
#   Episode  4500 | Recent avg:  121.6 | Epsilon: 0.010 | Best: 199
#   Episode  5000 | Recent avg:  118.4 | Epsilon: 0.010 | Best: 199
#   Episode  5500 | Recent avg:  124.7 | Epsilon: 0.010 | Best: 199
#   Episode  6000 | Recent avg:  128.8 | Epsilon: 0.010 | Best: 199
#   Episode  6500 | Recent avg:  132.9 | Epsilon: 0.010 | Best: 209
#   Episode  7000 | Recent avg:  126.4 | Epsilon: 0.010 | Best: 235
#   Episode  7500 | Recent avg:  120.4 | Epsilon: 0.010 | Best: 235
#   Episode  8000 | Recent avg:  128.6 | Epsilon: 0.010 | Best: 235
#   Episode  8500 | Recent avg:  128.0 | Epsilon: 0.010 | Best: 235
#   Episode  9000 | Recent avg:  127.0 | Epsilon: 0.010 | Best: 235
#   Episode  9500 | Recent avg:  132.9 | Epsilon: 0.010 | Best: 235
#   Episode 10000 | Recent avg:  163.9 | Epsilon: 0.010 | Best: 235
#   Episode 10500 | Recent avg:  148.1 | Epsilon: 0.010 | Best: 235
#   Episode 11000 | Recent avg:  151.8 | Epsilon: 0.010 | Best: 235
#   Episode 11500 | Recent avg:  160.7 | Epsilon: 0.010 | Best: 261
#   Episode 12000 | Recent avg:  147.2 | Epsilon: 0.010 | Best: 376
#   Episode 12500 | Recent avg:  167.8 | Epsilon: 0.010 | Best: 386
#   Episode 13000 | Recent avg:  149.0 | Epsilon: 0.010 | Best: 386
#   Episode 13500 | Recent avg:  147.2 | Epsilon: 0.010 | Best: 386
#   Episode 14000 | Recent avg:  175.5 | Epsilon: 0.010 | Best: 386
#   Episode 14500 | Recent avg:  181.5 | Epsilon: 0.010 | Best: 386
#   Episode 15000 | Recent avg:  144.6 | Epsilon: 0.010 | Best: 386
#   Episode 15500 | Recent avg:  163.4 | Epsilon: 0.010 | Best: 386
#   Episode 16000 | Recent avg:  174.7 | Epsilon: 0.010 | Best: 386
#   Episode 16500 | Recent avg:  177.5 | Epsilon: 0.010 | Best: 386
#   Episode 17000 | Recent avg:  184.9 | Epsilon: 0.010 | Best: 386
#   Episode 17500 | Recent avg:  189.1 | Epsilon: 0.010 | Best: 386
#   Episode 18000 | Recent avg:  172.5 | Epsilon: 0.010 | Best: 386
#   Episode 18500 | Recent avg:  193.4 | Epsilon: 0.010 | Best: 386
#   Episode 19000 | Recent avg:  143.2 | Epsilon: 0.010 | Best: 386
#   Episode 19500 | Recent avg:  180.6 | Epsilon: 0.010 | Best: 386
#   Episode 20000 | Recent avg:  162.9 | Epsilon: 0.010 | Best: 386
#   Episode 20500 | Recent avg:  169.5 | Epsilon: 0.010 | Best: 436
#   Episode 21000 | Recent avg:  155.0 | Epsilon: 0.010 | Best: 436
#   Episode 21500 | Recent avg:  144.7 | Epsilon: 0.010 | Best: 436
#   Episode 22000 | Recent avg:  135.0 | Epsilon: 0.010 | Best: 436
#   Episode 22500 | Recent avg:  158.9 | Epsilon: 0.010 | Best: 436
#   Episode 23000 | Recent avg:  161.4 | Epsilon: 0.010 | Best: 436
#   Episode 23500 | Recent avg:  140.9 | Epsilon: 0.010 | Best: 436
#   Episode 24000 | Recent avg:  167.2 | Epsilon: 0.010 | Best: 436
#   Episode 24500 | Recent avg:  163.1 | Epsilon: 0.010 | Best: 436
#   Episode 25000 | Recent avg:  158.3 | Epsilon: 0.010 | Best: 436
#   Episode 25500 | Recent avg:  136.8 | Epsilon: 0.010 | Best: 436
#   Episode 26000 | Recent avg:  143.7 | Epsilon: 0.010 | Best: 436
#   Episode 26500 | Recent avg:  146.9 | Epsilon: 0.010 | Best: 436
#   Episode 27000 | Recent avg:  170.4 | Epsilon: 0.010 | Best: 436
#   Episode 27500 | Recent avg:  167.8 | Epsilon: 0.010 | Best: 436
#   Episode 28000 | Recent avg:  151.1 | Epsilon: 0.010 | Best: 436
#   Episode 28500 | Recent avg:  163.4 | Epsilon: 0.010 | Best: 436
#   Episode 29000 | Recent avg:  159.1 | Epsilon: 0.010 | Best: 436
#   Episode 29500 | Recent avg:  151.3 | Epsilon: 0.010 | Best: 436
#   Episode 30000 | Recent avg:  148.8 | Epsilon: 0.010 | Best: 500
#   Episode 30500 | Recent avg:  137.5 | Epsilon: 0.010 | Best: 500
#   Episode 31000 | Recent avg:  159.6 | Epsilon: 0.010 | Best: 500
#   Episode 31500 | Recent avg:  149.7 | Epsilon: 0.010 | Best: 500
#   Episode 32000 | Recent avg:  156.9 | Epsilon: 0.010 | Best: 500
#   Episode 32500 | Recent avg:  150.9 | Epsilon: 0.010 | Best: 500
#   Episode 33000 | Recent avg:  167.2 | Epsilon: 0.010 | Best: 500
#   Episode 33500 | Recent avg:  154.1 | Epsilon: 0.010 | Best: 500
#   Episode 34000 | Recent avg:  140.1 | Epsilon: 0.010 | Best: 500
#   Episode 34500 | Recent avg:  150.7 | Epsilon: 0.010 | Best: 500
#   Episode 35000 | Recent avg:  155.9 | Epsilon: 0.010 | Best: 500
#   Episode 35500 | Recent avg:  146.2 | Epsilon: 0.010 | Best: 500
#   Episode 36000 | Recent avg:  180.8 | Epsilon: 0.010 | Best: 500
#   Episode 36500 | Recent avg:  157.9 | Epsilon: 0.010 | Best: 500
#   Episode 37000 | Recent avg:  162.4 | Epsilon: 0.010 | Best: 500
#   Episode 37500 | Recent avg:  156.7 | Epsilon: 0.010 | Best: 500
#   Episode 38000 | Recent avg:  181.5 | Epsilon: 0.010 | Best: 500
#   Episode 38500 | Recent avg:  156.2 | Epsilon: 0.010 | Best: 500
#   Episode 39000 | Recent avg:  157.4 | Epsilon: 0.010 | Best: 500
#   Episode 39500 | Recent avg:  176.9 | Epsilon: 0.010 | Best: 500
#   Episode 40000 | Recent avg:  188.9 | Epsilon: 0.010 | Best: 500
#   Episode 40500 | Recent avg:  165.7 | Epsilon: 0.010 | Best: 500
#   Episode 41000 | Recent avg:  177.8 | Epsilon: 0.010 | Best: 500
#   Episode 41500 | Recent avg:  177.9 | Epsilon: 0.010 | Best: 500
#   Episode 42000 | Recent avg:  142.2 | Epsilon: 0.010 | Best: 500
#   Episode 42500 | Recent avg:  153.9 | Epsilon: 0.010 | Best: 500
#   Episode 43000 | Recent avg:  136.1 | Epsilon: 0.010 | Best: 500
#   Episode 43500 | Recent avg:  162.6 | Epsilon: 0.010 | Best: 500
#   Episode 44000 | Recent avg:  175.3 | Epsilon: 0.010 | Best: 500
#   Episode 44500 | Recent avg:  153.3 | Epsilon: 0.010 | Best: 500
#   Episode 45000 | Recent avg:  176.4 | Epsilon: 0.010 | Best: 500
#   Episode 45500 | Recent avg:  161.4 | Epsilon: 0.010 | Best: 500
#   Episode 46000 | Recent avg:  181.3 | Epsilon: 0.010 | Best: 500
#   Episode 46500 | Recent avg:  174.9 | Epsilon: 0.010 | Best: 500
#   Episode 47000 | Recent avg:  163.9 | Epsilon: 0.010 | Best: 500
#   Episode 47500 | Recent avg:  163.2 | Epsilon: 0.010 | Best: 500
#   Episode 48000 | Recent avg:  193.6 | Epsilon: 0.010 | Best: 500
#   Episode 48500 | Recent avg:  131.0 | Epsilon: 0.010 | Best: 500
#   Episode 49000 | Recent avg:  178.2 | Epsilon: 0.010 | Best: 500
#   Episode 49500 | Recent avg:  181.3 | Epsilon: 0.010 | Best: 500
#   Episode 50000 | Recent avg:  159.3 | Epsilon: 0.010 | Best: 500
#   Episode 50500 | Recent avg:  175.5 | Epsilon: 0.010 | Best: 500
#   Episode 51000 | Recent avg:  168.6 | Epsilon: 0.010 | Best: 500
#   Episode 51500 | Recent avg:  163.8 | Epsilon: 0.010 | Best: 500
#   Episode 52000 | Recent avg:  182.7 | Epsilon: 0.010 | Best: 500
#   Episode 52500 | Recent avg:  141.9 | Epsilon: 0.010 | Best: 500
#   Episode 53000 | Recent avg:  143.3 | Epsilon: 0.010 | Best: 500
#   Episode 53500 | Recent avg:  151.3 | Epsilon: 0.010 | Best: 500
#   Episode 54000 | Recent avg:  134.1 | Epsilon: 0.010 | Best: 500
#   Episode 54500 | Recent avg:  130.4 | Epsilon: 0.010 | Best: 500
#   Episode 55000 | Recent avg:  178.9 | Epsilon: 0.010 | Best: 500
#   Episode 55500 | Recent avg:  150.4 | Epsilon: 0.010 | Best: 500
#   Episode 56000 | Recent avg:  163.4 | Epsilon: 0.010 | Best: 500
#   Episode 56500 | Recent avg:  176.3 | Epsilon: 0.010 | Best: 500
#   Episode 57000 | Recent avg:  138.4 | Epsilon: 0.010 | Best: 500
#   Episode 57500 | Recent avg:  174.5 | Epsilon: 0.010 | Best: 500
#   Episode 58000 | Recent avg:  138.8 | Epsilon: 0.010 | Best: 500
#   Episode 58500 | Recent avg:  170.0 | Epsilon: 0.010 | Best: 500
#   Episode 59000 | Recent avg:  148.1 | Epsilon: 0.010 | Best: 500
#   Episode 59500 | Recent avg:  170.9 | Epsilon: 0.010 | Best: 500
#   Episode 60000 | Recent avg:  165.0 | Epsilon: 0.010 | Best: 500
#   Episode 60500 | Recent avg:  169.4 | Epsilon: 0.010 | Best: 500
#   Episode 61000 | Recent avg:  160.4 | Epsilon: 0.010 | Best: 500
#   Episode 61500 | Recent avg:  181.2 | Epsilon: 0.010 | Best: 500
#   Episode 62000 | Recent avg:  125.7 | Epsilon: 0.010 | Best: 500
#   Episode 62500 | Recent avg:  156.0 | Epsilon: 0.010 | Best: 500
#   Episode 63000 | Recent avg:  141.5 | Epsilon: 0.010 | Best: 500
#   Episode 63500 | Recent avg:  162.2 | Epsilon: 0.010 | Best: 500
#   Episode 64000 | Recent avg:  153.0 | Epsilon: 0.010 | Best: 500
#   Episode 64500 | Recent avg:  152.4 | Epsilon: 0.010 | Best: 500
#   Episode 65000 | Recent avg:  134.1 | Epsilon: 0.010 | Best: 500
#   Episode 65500 | Recent avg:  155.9 | Epsilon: 0.010 | Best: 500
#   Episode 66000 | Recent avg:  157.4 | Epsilon: 0.010 | Best: 500
#   Episode 66500 | Recent avg:  181.1 | Epsilon: 0.010 | Best: 500
#   Episode 67000 | Recent avg:  166.0 | Epsilon: 0.010 | Best: 500
#   Episode 67500 | Recent avg:  136.5 | Epsilon: 0.010 | Best: 500
#   Episode 68000 | Recent avg:  139.6 | Epsilon: 0.010 | Best: 500
#   Episode 68500 | Recent avg:  141.4 | Epsilon: 0.010 | Best: 500
#   Episode 69000 | Recent avg:  181.0 | Epsilon: 0.010 | Best: 500
#   Episode 69500 | Recent avg:  178.0 | Epsilon: 0.010 | Best: 500
#   Episode 70000 | Recent avg:  143.4 | Epsilon: 0.010 | Best: 500
#   Episode 70500 | Recent avg:  140.0 | Epsilon: 0.010 | Best: 500
#   Episode 71000 | Recent avg:  156.6 | Epsilon: 0.010 | Best: 500
#   Episode 71500 | Recent avg:  166.0 | Epsilon: 0.010 | Best: 500
#   Episode 72000 | Recent avg:  145.9 | Epsilon: 0.010 | Best: 500
#   Episode 72500 | Recent avg:  177.8 | Epsilon: 0.010 | Best: 500
#   Episode 73000 | Recent avg:  167.5 | Epsilon: 0.010 | Best: 500
#   Episode 73500 | Recent avg:  162.7 | Epsilon: 0.010 | Best: 500
#   Episode 74000 | Recent avg:  156.2 | Epsilon: 0.010 | Best: 500
#   Episode 74500 | Recent avg:  142.9 | Epsilon: 0.010 | Best: 500
#   Episode 75000 | Recent avg:  140.6 | Epsilon: 0.010 | Best: 500
#   Episode 75500 | Recent avg:  179.3 | Epsilon: 0.010 | Best: 500
#   Episode 76000 | Recent avg:  176.4 | Epsilon: 0.010 | Best: 500
#   Episode 76500 | Recent avg:  133.4 | Epsilon: 0.010 | Best: 500
#   Episode 77000 | Recent avg:  144.3 | Epsilon: 0.010 | Best: 500
#   Episode 77500 | Recent avg:  175.5 | Epsilon: 0.010 | Best: 500
#   Episode 78000 | Recent avg:  139.4 | Epsilon: 0.010 | Best: 500
#   Episode 78500 | Recent avg:  141.6 | Epsilon: 0.010 | Best: 500
#   Episode 79000 | Recent avg:  153.4 | Epsilon: 0.010 | Best: 500
#   Episode 79500 | Recent avg:  148.3 | Epsilon: 0.010 | Best: 500
#   Episode 80000 | Recent avg:  143.3 | Epsilon: 0.010 | Best: 500
#   Episode 80500 | Recent avg:  185.9 | Epsilon: 0.010 | Best: 500
#   Episode 81000 | Recent avg:  134.7 | Epsilon: 0.010 | Best: 500
#   Episode 81500 | Recent avg:  180.8 | Epsilon: 0.010 | Best: 500
#   Episode 82000 | Recent avg:  190.5 | Epsilon: 0.010 | Best: 500
#   Episode 82500 | Recent avg:  168.6 | Epsilon: 0.010 | Best: 500
#   Episode 83000 | Recent avg:  162.7 | Epsilon: 0.010 | Best: 500
#   Episode 83500 | Recent avg:  152.5 | Epsilon: 0.010 | Best: 500
#   Episode 84000 | Recent avg:  151.8 | Epsilon: 0.010 | Best: 500
#   Episode 84500 | Recent avg:  166.8 | Epsilon: 0.010 | Best: 500
#   Episode 85000 | Recent avg:  140.4 | Epsilon: 0.010 | Best: 500
#   Episode 85500 | Recent avg:  173.3 | Epsilon: 0.010 | Best: 500
#   Episode 86000 | Recent avg:  184.5 | Epsilon: 0.010 | Best: 500
#   Episode 86500 | Recent avg:  157.3 | Epsilon: 0.010 | Best: 500
#   Episode 87000 | Recent avg:  173.4 | Epsilon: 0.010 | Best: 500
#   Episode 87500 | Recent avg:  140.5 | Epsilon: 0.010 | Best: 500
#   Episode 88000 | Recent avg:  138.2 | Epsilon: 0.010 | Best: 500
#   Episode 88500 | Recent avg:  197.5 | Epsilon: 0.010 | Best: 500
#   Episode 89000 | Recent avg:  179.1 | Epsilon: 0.010 | Best: 500
#   Episode 89500 | Recent avg:  126.3 | Epsilon: 0.010 | Best: 500
#   Episode 90000 | Recent avg:  153.5 | Epsilon: 0.010 | Best: 500
#   Episode 90500 | Recent avg:  148.0 | Epsilon: 0.010 | Best: 500
#   Episode 91000 | Recent avg:  135.9 | Epsilon: 0.010 | Best: 500
#   Episode 91500 | Recent avg:  160.4 | Epsilon: 0.010 | Best: 500
#   Episode 92000 | Recent avg:  149.0 | Epsilon: 0.010 | Best: 500
#   Episode 92500 | Recent avg:  161.0 | Epsilon: 0.010 | Best: 500
#   Episode 93000 | Recent avg:  159.9 | Epsilon: 0.010 | Best: 500
#   Episode 93500 | Recent avg:  144.7 | Epsilon: 0.010 | Best: 500
#   Episode 94000 | Recent avg:  172.5 | Epsilon: 0.010 | Best: 500
#   Episode 94500 | Recent avg:  151.8 | Epsilon: 0.010 | Best: 500
#   Episode 95000 | Recent avg:  141.4 | Epsilon: 0.010 | Best: 500
#   Episode 95500 | Recent avg:  167.2 | Epsilon: 0.010 | Best: 500
#   Episode 96000 | Recent avg:  128.5 | Epsilon: 0.010 | Best: 500
#   Episode 96500 | Recent avg:  144.8 | Epsilon: 0.010 | Best: 500
#   Episode 97000 | Recent avg:  175.8 | Epsilon: 0.010 | Best: 500
#   Episode 97500 | Recent avg:  165.6 | Epsilon: 0.010 | Best: 500
#   Episode 98000 | Recent avg:  155.3 | Epsilon: 0.010 | Best: 500
#   Episode 98500 | Recent avg:  164.4 | Epsilon: 0.010 | Best: 500
#   Episode 99000 | Recent avg:  164.7 | Epsilon: 0.010 | Best: 500
#   Episode 99500 | Recent avg:  166.1 | Epsilon: 0.010 | Best: 500
#   Episode 100000 | Recent avg:  164.8 | Epsilon: 0.010 | Best: 500

# %%
# Comprehensive results visualization
fig, axes = plt.subplots(2, 2, figsize=(14, 10))

# Plot 1: Learning curve
window = 50
smoothed = [np.mean(q_rewards[max(0,i-window):i+1]) for i in range(len(q_rewards))]
axes[0, 0].plot(smoothed, color='blue', alpha=0.8)
axes[0, 0].axhline(y=500, color='gold', linestyle='--', label='Max possible (500)')
axes[0, 0].axhline(y=np.mean(random_rewards_cartpole), color='red', linestyle='--', label=f'Random ({np.mean(random_rewards_cartpole):.0f})')
axes[0, 0].set_xlabel('Episode')
axes[0, 0].set_ylabel('Reward (smoothed)')
axes[0, 0].set_title('Q-Learning: Training Progress', fontsize=13, fontweight='bold')
axes[0, 0].legend()

# Plot 2: Histogram comparison (all three agents)
axes[0, 1].hist(random_rewards_cartpole, bins=20, alpha=0.5, label='Random', color='red', density=True)
axes[0, 1].hist(heuristic_rewards, bins=20, alpha=0.5, label='Heuristic', color='green', density=True)
axes[0, 1].hist(q_rewards[-100:], bins=20, alpha=0.5, label='Q-Learning (last 100)', color='blue', density=True)
axes[0, 1].set_xlabel('Episode Reward')
axes[0, 1].set_ylabel('Density')
axes[0, 1].set_title('Reward Distribution Comparison', fontsize=13, fontweight='bold')
axes[0, 1].legend()

# Plot 3: Bar chart of final performance
final_q_mean = np.mean(q_rewards[-100:])
means = [np.mean(random_rewards_cartpole), np.mean(heuristic_rewards), final_q_mean]
labels = ['Random', 'Heuristic', 'Q-Learning']
colors = ['red', 'green', 'blue']
bars = axes[1, 0].bar(labels, means, color=colors, alpha=0.7)
axes[1, 0].set_ylabel('Mean Reward')
axes[1, 0].set_title('Final Performance Comparison', fontsize=13, fontweight='bold')
axes[1, 0].axhline(y=500, color='gold', linestyle='--')
for bar, mean in zip(bars, means):
    axes[1, 0].text(bar.get_x() + bar.get_width()/2, bar.get_height() + 5,
                     f'{mean:.0f}', ha='center', fontsize=12, fontweight='bold')

# Plot 4: Q-table size over training
q_sizes = []
check_points = list(range(0, len(q_rewards), 100))
for i in check_points:
    q_sizes.append(min(i * 2, len(q_agent.q_table)))  # approximate
axes[1, 1].plot(check_points, q_sizes, 'purple', linewidth=2)
axes[1, 1].set_xlabel('Episode')
axes[1, 1].set_ylabel('Approx. States Explored')
axes[1, 1].set_title('State Space Exploration', fontsize=13, fontweight='bold')

plt.tight_layout()
plt.show()

print(f"\nFinal Results (last 100 episodes):")
print(f"  Random Agent:    {np.mean(random_rewards_cartpole):>6.1f} avg reward")
print(f"  Heuristic Agent: {np.mean(heuristic_rewards):>6.1f} avg reward")
print(f"  Q-Learning Agent: {final_q_mean:>6.1f} avg reward")
print(f"\n  Q-table entries: {len(q_agent.q_table)}")
# Out:
# Final Results (last 100 episodes):
#   Random Agent:      21.8 avg reward
#   Heuristic Agent:  500.0 avg reward
#   Q-Learning Agent:  164.8 avg reward
#
#   Q-table entries: 2160

# %%
# Evaluate the trained Q-learning agent (greedy, no exploration)
def evaluate_agent(agent, env_name='CartPole-v1', n_episodes=50):
    """Evaluate trained agent with no exploration."""
    env = gym.make(env_name)
    rewards = []

    for ep in range(n_episodes):
        obs, info = env.reset(seed=ep + 1000)
        state = agent.discretize(obs)
        total_reward = 0

        for step in range(500):
            action = np.argmax(agent.q_table[state])  # greedy
            obs, reward, terminated, truncated, info = env.step(action)
            state = agent.discretize(obs)
            total_reward += 1

            if terminated or truncated:
                break

        rewards.append(total_reward)

    env.close()
    return rewards

eval_rewards = evaluate_agent(q_agent)
print(f"Evaluation (50 episodes, greedy policy):")
print(f"  Mean: {np.mean(eval_rewards):.1f}")
print(f"  Std:  {np.std(eval_rewards):.1f}")
print(f"  Min:  {np.min(eval_rewards)}")
print(f"  Max:  {np.max(eval_rewards)}")
print(f"  Solved (>= 475 avg): {'YES' if np.mean(eval_rewards) >= 475 else 'Not yet -- try more training'}")
# Out:
# Evaluation (50 episodes, greedy policy):
#   Mean: 198.3
#   Std:  44.6
#   Min:  117
#   Max:  318
#   Solved (>= 475 avg): Not yet -- try more training

# %%
# Final interactive demo: step through one episode showing the learned Q-values

env = gym.make('CartPole-v1')
obs, info = env.reset(seed=99)
state = q_agent.discretize(obs)

print("Watching the trained Q-learning agent play one episode:")
print("=" * 80)
print(f"{'Step':>4} | {'Pole Angle':>11} | {'Action':>7} | {'Q(left)':>8} | {'Q(right)':>9} | {'Alive':>5}")
print("-" * 80)

for step in range(500):
    q_values = q_agent.q_table[state]
    action = np.argmax(q_values)
    action_name = 'LEFT' if action == 0 else 'RIGHT'

    print(f"{step:>4} | {obs[2]:>11.6f} | {action_name:>7} | {q_values[0]:>8.2f} | {q_values[1]:>9.2f} | {'yes':>5}")

    obs, reward, terminated, truncated, info = env.step(action)
    state = q_agent.discretize(obs)

    if terminated or truncated:
        print(f"\nEpisode ended at step {step+1}")
        break

    # Only show first 15 and last 5 steps to avoid clutter
    if step == 15:
        print(f"  ... (skipping middle steps for brevity) ...")
    if 15 < step < max(0, step - 5):
        continue

env.close()

print(f"\nThe agent survived {step+1} steps by choosing actions based on learned Q-values.")
print("Notice how Q(left) and Q(right) change based on the pole angle --")
print("the agent learned which action is better in each state, purely from experience.")
# Out:
# Watching the trained Q-learning agent play one episode:
# ================================================================================
# Step |  Pole Angle |  Action |  Q(left) |  Q(right) | Alive
# --------------------------------------------------------------------------------
#    0 |    0.001192 |   RIGHT |    70.30 |     72.20 |   yes
#    1 |    0.002136 |   RIGHT |    70.30 |     72.20 |   yes
#    2 |   -0.002766 |   RIGHT |    68.91 |     69.84 |   yes
#    3 |   -0.013508 |    LEFT |    69.81 |     66.64 |   yes
#    4 |   -0.030121 |    LEFT |    69.87 |     67.83 |   yes
#    5 |   -0.040966 |    LEFT |    72.38 |     69.15 |   yes
#    6 |   -0.046150 |    LEFT |    72.38 |     69.15 |   yes
#    7 |   -0.045744 |   RIGHT |    70.73 |     72.18 |   yes
#    8 |   -0.039783 |    LEFT |    72.38 |     69.15 |   yes
#    9 |   -0.039957 |    LEFT |    72.38 |     69.15 |   yes
#   10 |   -0.034533 |   RIGHT |    68.10 |     72.81 |   yes
#   11 |   -0.023514 |    LEFT |    72.38 |     69.15 |   yes
#   12 |   -0.018561 |   RIGHT |    66.68 |     72.63 |   yes
#   13 |   -0.007905 |   RIGHT |    70.30 |     72.20 |   yes
#   14 |   -0.003218 |   RIGHT |    70.30 |     72.20 |   yes
#   15 |   -0.004435 |    LEFT |    72.83 |     69.85 |   yes
#   ... (skipping middle steps for brevity) ...
#   16 |   -0.011525 |   RIGHT |    70.30 |     72.20 |   yes
#   17 |   -0.012790 |    LEFT |    72.83 |     69.85 |   yes
#   18 |   -0.019981 |    LEFT |    72.38 |     69.15 |   yes
#   19 |   -0.021400 |    LEFT |    72.38 |     69.15 |   yes
#   20 |   -0.017092 |   RIGHT |    66.68 |     72.63 |   yes
#   21 |   -0.007067 |   RIGHT |    70.30 |     72.20 |   yes
#   22 |   -0.003003 |   RIGHT |    70.30 |     72.20 |   yes
#   23 |   -0.004836 |    LEFT |    72.83 |     69.85 |   yes
#   24 |   -0.012542 |   RIGHT |    70.30 |     72.20 |   yes
#   25 |   -0.014425 |    LEFT |    72.83 |     69.85 |   yes
#   26 |   -0.022241 |    LEFT |    72.38 |     69.15 |   yes
#   27 |   -0.024294 |    LEFT |    72.38 |     69.15 |   yes
#   28 |   -0.020636 |   RIGHT |    68.10 |     72.81 |   yes
#   29 |   -0.011279 |   RIGHT |    70.30 |     72.20 |   yes
#   30 |   -0.007905 |   RIGHT |    70.30 |     72.20 |   yes
#   31 |   -0.010454 |    LEFT |    72.83 |     69.85 |   yes
#   32 |   -0.018908 |   RIGHT |    70.30 |     72.20 |   yes
#   33 |   -0.021574 |    LEFT |    70.92 |     67.22 |   yes
#   34 |   -0.030211 |    LEFT |    72.38 |     69.15 |   yes
#   35 |   -0.033133 |    LEFT |    72.38 |     69.15 |   yes
#   36 |   -0.030394 |   RIGHT |    68.10 |     72.81 |   yes
#   37 |   -0.022015 |    LEFT |    72.38 |     69.15 |   yes
#   38 |   -0.019677 |   RIGHT |    68.10 |     72.81 |   yes
#   39 |   -0.011627 |   RIGHT |    70.30 |     72.20 |   yes
#   40 |   -0.009553 |   RIGHT |    70.30 |     72.20 |   yes
#   41 |   -0.013406 |    LEFT |    72.83 |     69.85 |   yes
#   42 |   -0.023172 |    LEFT |    72.38 |     69.15 |   yes
#   43 |   -0.027169 |    LEFT |    72.38 |     69.15 |   yes
#   44 |   -0.025461 |   RIGHT |    68.10 |     72.81 |   yes
#   45 |   -0.018073 |   RIGHT |    70.30 |     72.20 |   yes
#   46 |   -0.016698 |   RIGHT |    70.30 |     72.20 |   yes
#   47 |   -0.021288 |    LEFT |    70.92 |     67.22 |   yes
#   48 |   -0.031837 |    LEFT |    72.38 |     69.15 |   yes
#   49 |   -0.036668 |    LEFT |    72.38 |     69.15 |   yes
#   50 |   -0.035849 |   RIGHT |    68.10 |     72.81 |   yes
#   51 |   -0.029413 |    LEFT |    72.38 |     69.15 |   yes
#   52 |   -0.029052 |   RIGHT |    68.10 |     72.81 |   yes
#   53 |   -0.023026 |    LEFT |    72.38 |     69.15 |   yes
#   54 |   -0.023033 |   RIGHT |    68.10 |     72.81 |   yes
#   55 |   -0.017335 |   RIGHT |    70.30 |     72.20 |   yes
#   56 |   -0.017633 |    LEFT |    72.83 |     69.85 |   yes
#   57 |   -0.023893 |    LEFT |    72.38 |     69.15 |   yes
#   58 |   -0.024412 |   RIGHT |    66.98 |     70.13 |   yes
#   59 |   -0.019230 |    LEFT |    72.38 |     69.15 |   yes
#   60 |   -0.020054 |   RIGHT |    66.98 |     70.13 |   yes
#   61 |   -0.015146 |   RIGHT |    70.30 |     72.20 |   yes
#   62 |   -0.016218 |    LEFT |    72.83 |     69.85 |   yes
#   63 |   -0.023237 |    LEFT |    72.38 |     69.15 |   yes
#   64 |   -0.024507 |   RIGHT |    66.98 |     70.13 |   yes
#   65 |   -0.020071 |    LEFT |    72.38 |     69.15 |   yes
#   66 |   -0.021641 |   RIGHT |    66.98 |     70.13 |   yes
#   67 |   -0.017486 |   RIGHT |    70.30 |     72.20 |   yes
#   68 |   -0.019319 |    LEFT |    70.92 |     67.22 |   yes
#   69 |   -0.027115 |    LEFT |    72.38 |     69.15 |   yes
#   70 |   -0.029180 |   RIGHT |    66.98 |     70.13 |   yes
#   71 |   -0.025566 |    LEFT |    72.38 |     69.15 |   yes
#   72 |   -0.027986 |   RIGHT |    66.98 |     70.13 |   yes
#   73 |   -0.024716 |    LEFT |    72.38 |     69.15 |   yes
#   74 |   -0.027474 |   RIGHT |    66.98 |     70.13 |   yes
#   75 |   -0.024536 |    LEFT |    72.38 |     69.15 |   yes
#   76 |   -0.027622 |   RIGHT |    66.98 |     70.13 |   yes
#   77 |   -0.025012 |    LEFT |    72.38 |     69.15 |   yes
#   78 |   -0.028427 |   RIGHT |    66.98 |     70.13 |   yes
#   79 |   -0.026148 |    LEFT |    72.38 |     69.15 |   yes
#   80 |   -0.029900 |   RIGHT |    66.98 |     70.13 |   yes
#   81 |   -0.027965 |    LEFT |    72.38 |     69.15 |   yes
#   82 |   -0.032069 |   RIGHT |    66.98 |     70.13 |   yes
#   83 |   -0.030499 |    LEFT |    72.38 |     69.15 |   yes
#   84 |   -0.034981 |   RIGHT |    66.98 |     70.13 |   yes
#   85 |   -0.033805 |    LEFT |    72.38 |     69.15 |   yes
#   86 |   -0.038699 |   RIGHT |    66.98 |     70.13 |   yes
#   87 |   -0.037957 |    LEFT |    72.38 |     69.15 |   yes
#   88 |   -0.043307 |   RIGHT |    66.98 |     70.13 |   yes
#   89 |   -0.043048 |    LEFT |    70.92 |     67.22 |   yes
#   90 |   -0.048910 |   RIGHT |    66.98 |     70.13 |   yes
#   91 |   -0.049195 |    LEFT |    51.53 |     50.68 |   yes
#   92 |   -0.055635 |   RIGHT |    50.63 |     51.56 |   yes
#   93 |   -0.056539 |    LEFT |    51.53 |     50.68 |   yes
#   94 |   -0.063637 |    LEFT |    49.59 |     48.85 |   yes
#   95 |   -0.065249 |    LEFT |    49.59 |     48.85 |   yes
#   96 |   -0.061421 |   RIGHT |    49.86 |     51.65 |   yes
#   97 |   -0.052166 |   RIGHT |    50.63 |     51.56 |   yes
#   98 |   -0.049138 |   RIGHT |    50.63 |     51.56 |   yes
#   99 |   -0.052284 |    LEFT |    51.53 |     50.68 |   yes
#  100 |   -0.061585 |    LEFT |    49.59 |     48.85 |   yes
#  101 |   -0.065371 |    LEFT |    49.59 |     48.85 |   yes
#  102 |   -0.063705 |   RIGHT |    49.86 |     51.65 |   yes
#  103 |   -0.056611 |   RIGHT |    50.63 |     51.56 |   yes
#  104 |   -0.055758 |   RIGHT |    50.63 |     51.56 |   yes
#  105 |   -0.061106 |    LEFT |    49.85 |     47.64 |   yes
#  106 |   -0.072648 |    LEFT |    49.93 |     46.41 |   yes
#  107 |   -0.078733 |    LEFT |    49.59 |     48.85 |   yes
#  108 |   -0.079440 |    LEFT |    49.59 |     48.85 |   yes
#  109 |   -0.074811 |   RIGHT |    46.34 |     51.83 |   yes
#  110 |   -0.064849 |    LEFT |    49.59 |     48.85 |   yes
#  111 |   -0.061193 |   RIGHT |    46.34 |     51.83 |   yes
#  112 |   -0.052107 |   RIGHT |    50.63 |     51.56 |   yes
#  113 |   -0.049247 |   RIGHT |    50.63 |     51.56 |   yes
#  114 |   -0.052560 |    LEFT |    51.66 |     48.55 |   yes
#  115 |   -0.062029 |    LEFT |    49.59 |     48.85 |   yes
#  116 |   -0.065985 |    LEFT |    49.59 |     48.85 |   yes
#  117 |   -0.064491 |   RIGHT |    46.34 |     51.83 |   yes
#  118 |   -0.057573 |    LEFT |    49.59 |     48.85 |   yes
#  119 |   -0.056902 |   RIGHT |    42.16 |     52.18 |   yes
#  120 |   -0.050752 |   RIGHT |    50.63 |     51.56 |   yes
#  121 |   -0.050802 |    LEFT |    51.66 |     48.55 |   yes
#  122 |   -0.057018 |   RIGHT |    50.63 |     51.56 |   yes
#  123 |   -0.057709 |    LEFT |    49.93 |     46.41 |   yes
#  124 |   -0.064603 |    LEFT |    49.59 |     48.85 |   yes
#  125 |   -0.066017 |   RIGHT |    45.78 |     50.18 |   yes
#  126 |   -0.062000 |    LEFT |    49.59 |     48.85 |   yes
#  127 |   -0.064237 |   RIGHT |    45.78 |     50.18 |   yes
#  128 |   -0.061024 |    LEFT |    49.59 |     48.85 |   yes
#  129 |   -0.064056 |    LEFT |    35.11 |     31.80 |   yes
#  130 |   -0.061632 |   RIGHT |    30.88 |     34.81 |   yes
#  131 |   -0.053771 |    LEFT |    32.06 |     24.15 |   yes
#  132 |   -0.052140 |    LEFT |    31.59 |     25.87 |   yes
#  133 |   -0.045004 |    LEFT |    31.59 |     25.87 |   yes
#  134 |   -0.032352 |    LEFT |    30.63 |     20.60 |   yes
#  135 |   -0.014136 |    LEFT |    30.19 |     23.94 |   yes
#  136 |    0.009727 |    LEFT |    29.00 |      9.84 |   yes
#  137 |    0.039354 |   RIGHT |     7.47 |     29.98 |   yes
#  138 |    0.074895 |   RIGHT |    10.74 |     28.74 |   yes
#  139 |    0.104832 |   RIGHT |    10.39 |     28.70 |   yes
#  140 |    0.129401 |   RIGHT |    10.39 |     28.70 |   yes
#  141 |    0.148809 |   RIGHT |    15.74 |     27.92 |   yes
#  142 |    0.163229 |   RIGHT |    15.74 |     27.92 |   yes
#  143 |    0.172800 |   RIGHT |    -1.63 |     28.37 |   yes
#  144 |    0.177630 |   RIGHT |    18.79 |     36.31 |   yes
#  145 |    0.177788 |   RIGHT |    27.16 |     31.82 |   yes
#  146 |    0.173310 |    LEFT |    31.94 |     23.34 |   yes
#  147 |    0.164197 |    LEFT |    30.99 |     24.08 |   yes
#  148 |    0.161922 |    LEFT |    30.99 |     24.08 |   yes
#  149 |    0.166440 |   RIGHT |     8.02 |     29.02 |   yes
#  150 |    0.177740 |   RIGHT |     7.00 |     32.92 |   yes
#  151 |    0.184320 |   RIGHT |    27.16 |     31.82 |   yes
#  152 |    0.186264 |   RIGHT |    27.16 |     31.82 |   yes
#  153 |    0.183622 |    LEFT |    31.02 |     26.14 |   yes
#  154 |    0.176407 |   RIGHT |    27.16 |     31.82 |   yes
#  155 |    0.176083 |   RIGHT |    22.99 |     29.69 |   yes
#  156 |    0.171113 |    LEFT |    29.23 |     19.02 |   yes
#  157 |    0.161495 |   RIGHT |    27.35 |     29.30 |   yes
#  158 |    0.158705 |    LEFT |    29.23 |     19.02 |   yes
#  159 |    0.151161 |   RIGHT |    27.35 |     29.30 |   yes
#  160 |    0.150381 |    LEFT |    29.23 |     19.02 |   yes
#  161 |    0.144772 |   RIGHT |    27.35 |     29.30 |   yes
#  162 |    0.145885 |   RIGHT |    27.35 |     29.30 |   yes
#  163 |    0.142124 |    LEFT |    29.23 |     19.02 |   yes
#  164 |    0.133495 |    LEFT |    23.50 |     10.94 |   yes
#  165 |    0.131545 |    LEFT |    23.50 |     10.94 |   yes
#  166 |    0.136227 |   RIGHT |     8.29 |     29.66 |   yes
#  167 |    0.147532 |   RIGHT |    16.39 |     22.23 |   yes
#  168 |    0.153899 |   RIGHT |    27.35 |     29.30 |   yes
#  169 |    0.155411 |   RIGHT |    27.35 |     29.30 |   yes
#  170 |    0.152115 |    LEFT |    26.65 |     12.34 |   yes
#  171 |    0.144020 |   RIGHT |    27.35 |     29.30 |   yes
#  172 |    0.142655 |    LEFT |    26.65 |     12.34 |   yes
#  173 |    0.136411 |   RIGHT |    27.35 |     29.30 |   yes
#  174 |    0.136847 |   RIGHT |    19.91 |     26.14 |   yes
#  175 |    0.132349 |    LEFT |    22.99 |      5.72 |   yes
#  176 |    0.122919 |    LEFT |    18.47 |      3.26 |   yes
#  177 |    0.120116 |    LEFT |    23.50 |     10.94 |   yes
#  178 |    0.123888 |    LEFT |    21.62 |      6.71 |   yes
#  179 |    0.134221 |   RIGHT |    -0.01 |     10.85 |   yes
#  180 |    0.151134 |   RIGHT |    16.39 |     22.23 |   yes
#  181 |    0.163094 |   RIGHT |    16.39 |     22.23 |   yes
#  182 |    0.170223 |   RIGHT |    19.91 |     26.14 |   yes
#  183 |    0.172610 |   RIGHT |    17.44 |     27.56 |   yes
#  184 |    0.170307 |    LEFT |    26.65 |     12.34 |   yes
#  185 |    0.163331 |   RIGHT |    19.91 |     26.14 |   yes
#  186 |    0.163178 |   RIGHT |    19.91 |     26.14 |   yes
#  187 |    0.158285 |    LEFT |    24.13 |     10.84 |   yes
#  188 |    0.148650 |    LEFT |    33.71 |     29.21 |   yes
#  189 |    0.145776 |    LEFT |    33.71 |     29.21 |   yes
#  190 |    0.149616 |   RIGHT |    20.84 |     31.03 |   yes
#  191 |    0.160153 |   RIGHT |    20.84 |     31.03 |   yes
#  192 |    0.165849 |    LEFT |    33.71 |     29.21 |   yes
#  193 |    0.166781 |   RIGHT |    20.84 |     31.03 |   yes
#  194 |    0.174515 |   RIGHT |    30.66 |     35.26 |   yes
#  195 |    0.177533 |   RIGHT |    28.07 |     31.72 |   yes
#  196 |    0.175892 |    LEFT |    33.07 |     19.24 |   yes
#  197 |    0.169614 |    LEFT |    27.78 |     17.16 |   yes
#  198 |    0.170187 |   RIGHT |    20.84 |     31.03 |   yes
#  199 |    0.177582 |   RIGHT |    28.07 |     31.72 |   yes
#  200 |    0.180285 |   RIGHT |    28.07 |     31.72 |   yes
#  201 |    0.178352 |    LEFT |    33.07 |     19.24 |   yes
#  202 |    0.171802 |    LEFT |    27.78 |     17.16 |   yes
#  203 |    0.172116 |   RIGHT |     9.59 |     18.19 |   yes
#  204 |    0.179262 |   RIGHT |    28.07 |     31.72 |   yes
#  205 |    0.181731 |   RIGHT |    28.07 |     31.72 |   yes
#  206 |    0.179576 |    LEFT |    30.04 |     18.40 |   yes
#  207 |    0.172815 |   RIGHT |    28.07 |     31.72 |   yes
#  208 |    0.172924 |   RIGHT |     7.31 |     28.95 |   yes
#  209 |    0.168361 |    LEFT |    26.89 |      2.79 |   yes
#  210 |    0.159128 |    LEFT |    25.88 |      0.00 |   yes
#  211 |    0.156709 |    LEFT |    30.28 |     18.58 |   yes
#  212 |    0.161056 |   RIGHT |    11.00 |     28.42 |   yes
#  213 |    0.172158 |   RIGHT |     2.35 |     22.03 |   yes
#  214 |    0.178501 |   RIGHT |    23.44 |     26.74 |   yes
#  215 |    0.180168 |   RIGHT |    23.44 |     26.74 |   yes
#  216 |    0.177205 |    LEFT |    28.97 |     11.56 |   yes
#  217 |    0.169625 |    LEFT |    26.55 |     12.30 |   yes
#  218 |    0.168903 |   RIGHT |     2.77 |     25.55 |   yes
#  219 |    0.175001 |   RIGHT |    23.44 |     26.74 |   yes
#  220 |    0.176399 |   RIGHT |    23.44 |     26.74 |   yes
#  221 |    0.173142 |    LEFT |    25.28 |      2.41 |   yes
#  222 |    0.165240 |    LEFT |    26.55 |     12.30 |   yes
#  223 |    0.164175 |   RIGHT |     2.77 |     25.55 |   yes
#  224 |    0.169909 |    LEFT |    23.47 |      8.13 |   yes
#  225 |    0.170908 |    LEFT |    16.33 |      2.59 |   yes
#  226 |    0.178729 |   RIGHT |     0.97 |      9.52 |   yes
#  227 |    0.193376 |   RIGHT |     0.97 |      9.52 |   yes
#  228 |    0.203393 |   RIGHT |     0.97 |      9.52 |   yes
#  229 |    0.208889 |   RIGHT |     6.81 |     21.08 |   yes
#
# Episode ended at step 230
#
# The agent survived 230 steps by choosing actions based on learned Q-values.
# Notice how Q(left) and Q(right) change based on the pole angle --
# the agent learned which action is better in each state, purely from experience.
